# %% [markdown]
# <h1 style="text-align:center;">Лабораторна робота №3</h1>
# <p><b>Тема.</b> Аналіз складності алгоритмів. Алгоритми сортування</p>
# <p><b>Мета:</b> засвоїти аналіз складності алгоритмів як технологію на прикладі алгоритмів сортування методами включення та обміну.</p>

# %% [markdown]
# <p style="text-align:center;"><b>Порядок виконання роботи</b></p>

# %% [markdown]
# <p>1. Завантажити Python Anaconda та активувати в ньому віртуальне
# середовище, створене під час виконання попередньої лабораторної роботи.</p>
# <img src="figure-html\scr1.jpg" />

# %% [markdown]
# <p>2. Створити Notebook-документ <lab_2_StudentLastName> за допомогою
# Jupyter Notebook (лаб. роб № 1).</p>
# <img
#   src="figure-html\scr2.jpg"
#   alt=""
#   width="980"
#   height="500"/>

# %% [markdown]
# <p>3. Виконати теоретичні розрахунки асимптотичної складності алгоритмів
# сортування методами вставляння та бульбашки</p>
# <h4 style="text-align:center;">Аналіз асимптотичної складності алгоритмів</h4>
# <p><strong>1. Сортування вставками (Insertion Sort)</strong></p>
# <p><strong>Опис алгоритму:</strong> Сортування вставками проходить по масиву зліва направо, вставляючи кожен новий елемент у вже відсортовану частину масиву. При цьому, для кожного елемента знаходиться його позиція в відсортованій частині і здійснюються зсуви елементів, щоб звільнити місце.</p>
# <p>Асимптотична складність:</p>
# <ul>
#         <li>Найгірший випадок (O(n²)): <p>У найгіршому випадку (коли масив відсортований у зворотному порядку), кожен новий елемент потрібно перемістити на самий початок відсортованої частини. Для цього алгоритм порівнює поточний елемент із усіма попередніми, що потребує O(n) операцій для кожного з n елементів. Таким чином, загальна кількість операцій становить O(n2).</p></li>
#         <li>Найкращий випадок (O(n)):<p>У найкращому випадку (коли масив вже відсортований), алгоритм просто проходить по масиву і порівнює кожен елемент з попереднім, не здійснюючи зсувів. У такому випадку складність буде лінійною — O(n).</p></li>
#         <li>Середній випадок (O(n²)):<p>Середній випадок також має квадратичну складність O(n2), оскільки для вставки кожного елемента у середньому потрібно виконати половину зсувів, що призводить до квадратичної кількості операцій.</p></li>
#     </ul>
# <p><strong>2. Сортування бульбашкою (Bubble Sort)</strong></p>
# <p><strong>Опис алгоритму:</strong> Сортування бульбашкою працює шляхом багаторазового проходження по масиву, порівнюючи сусідні елементи і міняючи їх місцями, якщо вони стоять у неправильному порядку. Кожна ітерація "вспливає" найбільший невідсортований елемент до кінця масиву, тому після кожної ітерації кількість елементів для перевірки зменшується.</p>
# <p>Асимптотична складність:</p>
# <ul>
#     <li>Найгірший випадок (O(n²)):<p>У найгіршому випадку (коли масив відсортований у зворотному порядку) алгоритм буде виконувати n порівнянь за кожну ітерацію і переставляти елементи на кожному кроці. Для n елементів потрібно виконати O(n2) операцій.</p></li>
#     <li>Найкращий випадок (O(n)):<p>У найкращому випадку (коли масив вже відсортований), алгоритм проходить масив один раз і виявляє, що перестановки не потрібні. Це можна оптимізувати, додавши прапорець, який припиняє виконання алгоритму, якщо перестановок не було. Тому у найкращому випадку складність буде 𝑂(𝑛).</p></li>
#     <li>Середній випадок (O(n²)):<p>У середньому випадку алгоритм також має складність 𝑂(𝑛2), оскільки для впорядкування елементів середній час буде близьким до найгіршого випадку.</p></li>
# </ul>

# %% [markdown]
# <p>4. Реалізувати на Python алгоритм сортування методом бульбашки.</p>
# <img
#   src="figure-html\scr3.jpg"
#   alt=""
#   width="980"
#   height="265"/>

# %% [markdown]
# <p>5. Дослідити реальний час виконання обох алгоритмів на Python і
# побудувати графіки залежностей 𝑇𝑖𝑛𝑠𝑒𝑟𝑡(𝑛) та 𝑇𝑏𝑢𝑏𝑙𝑒(𝑛) для 𝑛 = [5, 10, 50, 100, 500, 1000, 2000, 3000, 4000, 5000, 10000, 20000, 50000, 10000], згенерувавши відповідні цілочисельні масиви.</p>

# %%
import time
import random
import matplotlib.pyplot as plt

def insertion_sort(nums):
    for j in range(1, len(nums)):
        key = nums[j]
        i = j - 1
        while i >= 0 and nums[i] > key:
            nums[i + 1] = nums[i]
            i -= 1
        nums[i + 1] = key

def bubble_sort(nums):
    n = len(nums)
    for i in range(n):
        for j in range(0, n-i-1):
            if nums[j] > nums[j+1]:
                nums[j], nums[j+1] = nums[j+1], nums[j]

sizes = [5, 10, 50, 100, 500, 1000, 2000, 3000, 4000, 5000, 10000, 20000, 50000, 10000]
insertion_times = []
bubble_times = []

for size in sizes:
    array = [random.randint(0, 10000) for _ in range(size)]

    start_time = time.time()
    insertion_sort(array.copy())
    insertion_times.append(time.time() - start_time)

    start_time = time.time()
    bubble_sort(array.copy())
    bubble_times.append(time.time() - start_time)

if len(sizes) == len(bubble_times) == len(insertion_times):
    plt.figure(figsize=(10, 6))
    plt.plot(sizes, insertion_times, label='Insertion Sort', marker='o')
    plt.plot(sizes, bubble_times, label='Bubble Sort', marker='o')
    plt.xlabel('Розмір масиву (n)')
    plt.ylabel('Час виконання (секунди)')
    plt.title('Порівняння часу виконання алгоритмів сортування')
    plt.legend()
    plt.grid(True)
    plt.xscale('log')
    plt.yscale('log')
    plt.show()

# %% [markdown]
# <img src="figure-html\Figure_1.jpeg" />

# %% [markdown]
# <p style="text-align:center;"><strong>Контрольні питання</strong></p>

# %% [markdown]
# <p>1. Що таке 𝑂-нотація і чим вона відрізняється від Ω -нотації?</p>
# <ul>
#     <li>O-нотація (Big-O) описує верхню границю часу виконання алгоритму у найгіршому випадку. Це означає, що алгоритм не займе більше часу, ніж передбачено O-нотацією, при великих значеннях вхідного розміру. Наприклад, якщо алгоритм має часову складність O(n2), то для великих значень 𝑛 він не буде працювати довше, ніж пропорційно 𝑛2.</li>
#     <li>Ω-нотація (Big-Omega) описує нижню границю часу виконання, тобто мінімальний час, необхідний для виконання алгоритму у найкращому випадку. Наприклад, для алгоритму з часовою складністю Ω(𝑛), час виконання буде як мінімум лінійним при великих значеннях n.</li>
# </ul>
# Отже, різниця між O-нотацією і Ω-нотацією в тому, що перша характеризує найгірший сценарій, тоді як друга — найкращий.

# %% [markdown]
# <p>2. Яку часову складність має алгоритм сортування методом вставляння за найсприятливіших умов, коли масив відсортовано? Відповідь обґрунтувати.</p>
# За найсприятливіших умов, коли масив вже відсортований, часова складність алгоритму сортування вставками складає 𝑂(𝑛). Це обумовлено тим, що для кожного елемента алгоритм лише перевіряє, чи він менший за попередній елемент, і жодного разу не виконує перестановок. Таким чином, кожна ітерація зовнішнього циклу триває константний час, що дає лінійну складність.

# %% [markdown]
# <p>3. Надати визначення ефективного алгоритму.</p>
# Ефективний алгоритм — це алгоритм, який вирішує поставлену задачу за найменший можливий обсяг ресурсів, як-то час і пам'ять, для даного класу задач. Ефективність зазвичай виражається у вигляді часової та просторової складності. Ефективні алгоритми мають, як правило, низьку асимптотичну складність, що дозволяє їм працювати швидше та з меншими затратами пам’яті при збільшенні обсягу даних.

# %% [markdown]
# <p>4. Пояснити поняття головного параметра (розміру) завдання.</p>
# Головний параметр (або розмір завдання) — це характеристика вхідних даних, яка найбільше впливає на складність алгоритму. Наприклад, у задачах сортування головним параметром зазвичай є кількість елементів у масиві n. Часова і просторова складність часто оцінюються в залежності від цього параметра.

# %% [markdown]
# <p>5. Функція часової складності має вигляд: 𝐹(𝑁)=𝑁3+7𝑁2−14𝑁. Як записати асимптотичну складність у 𝑂-нотації?</p>
# Асимптотична складність у O-нотації для функції F(N)=N3+7N2−14N визначається за домінуючим членом при великих значеннях N, тобто найбільшою степінню N. У даному випадку це N3. Отже, асимптотична складність дорівнює 𝑂(𝑁3).
